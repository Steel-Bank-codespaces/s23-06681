# %% [markdown]
# ---

# %% [markdown]
# # Project proposal
#
# Your project will be an original application of the topics we studied in this
# class. You have some options. You could
#
# 1. Find an interesting data set relevant to your field and do some analysis on it, e.g. fit a model, etc.
# 2. You could find an interesting data science type of package to build a tutorial application for that is relevant to to your field
# 3. Other interesting idea
#
# Eventually you will turn in a PDF derived from a notebook that is a full narrative document with the code used to implement your project. I am anticipating it will take you 8-10 hours to complete this, and your project scope should match that expectation.
#
# The purpose of this assignment is for you to propose an idea for your project to get initial feedback on the idea.
#
# Prepare about a 1-page description of what your project will be about. There should be enough detail for me to evaluate its suitability. You could include some pseduocode examples if you want, to illustrate what you are thinking about.
#
# Make sure you address:
# 1. What the relevance of your project to the class is.
# 2. How the dataset is relevant to your your field.
#
# You will get feedback on your project in Canvas.
#
# ## Project timeline
# 1. Proposal due 2/13/2023
# 2. Project check-in 2/20/2023
# 2. Presentations: 2/22 - 3/1/2023
# 4. Project report: 3/1/2023

# %% [markdown]
# # Summary of project
#
# Write a summary of your project idea below. You should include specific details on what you will do, how you will know it is succeeding, etc.

# %% [markdown]
# # Tasks to be completed and timeline
#
# Describe the things you will need to do to complete your project. For each task, estimate how long you think it will take, and when they will be completed by. Estimate the total amount of time you will need to do the project.
#
# Include an example of a proof of concept example that would show it is feasible (you do not need to demonstrate that yet, but it is the next assignment to do that).
