# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = ""
COLLABORATORS = ""

# %% [markdown]
# ---

# %% [markdown]
# # Reading data files

# %% [markdown]
# ## Thermal expansion data
#
# Go to https://www.itl.nist.gov/div898/handbook/pmd/section6/pmd641.htm. Download the [text file](https://www.itl.nist.gov/div898/handbook/datasets/HAHN1.DAT) containing the data on copper thermal expansion. You should be able to right click on the link in the NIST page (it does not work like this in the Jupyter notebook) and choose something like save as, save the file to your computer, and drag it into the jupyter lab file tab. Alternatively, click the up arrow in the file tab to upload the file. Read this data into numpy, and make a plot of the coefficient of thermal expansion vs. Temperature.
#
# Compare your results to https://www.itl.nist.gov/div898/handbook/pmd/section6/pmd643.htm. Discuss any differences.

# %% [markdown]
# ## Molecular data
#
# Download the data file from https://raw.githubusercontent.com/jkitchin/dft-book/master/molecules/isobutane.xyz.
#
# A convenient shell command to download this file is:
#
#     wget https://raw.githubusercontent.com/jkitchin/dft-book/master/molecules/isobutane.xyz
#
# Use that to get the data file.
#
# This is an xyz file containing the geometry of an isobutane molecule. Load this data into a numpy using np.loadtxt. Once you have the array, make an array of the chemical symbols, and a 2D array containing the x,y,z coordinates of each atom in each row.

# %% [markdown]
# # Manually parsing the molecular data
#
# Write some code that manually parses the isobutane.xyz file to get an array of the chemical symbols, and a 2D array containing the x,y,z coordinates of each atom in each row. Compare this result to the previous result and show they are the same.
#
# Compare the two approaches in terms of advantages and disadvantages.

# %%
# Run this cell to generate a pdf from this notebook
# Click the generated links to preview and download it.
# Report errors to Professor Kitchin
from s23 import webpdf
# %webpdf
